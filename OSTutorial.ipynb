# %%
import os

# %%
print(dir(os))
# Out:
# ['DirEntry', 'F_OK', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_putenv', '_unsetenv', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 'get_ex
# ...

# %%
print(os.getcwd())
# Out:
# c:\Users\Stacy\Documents

# %%
os.chdir('/Users/Stacy/Documents/')

# %%
print(os.listdir())
# Out:
# ['blah.png', 'Clinical Orientation Confirmation.png', 'Clinical Orientation Confirmation.tiff', 'Computer Science Fundamentals 6806', 'desktop.ini', 'Diablo III', 'Document4.docx', 'Fax1', 'GitHub', 'Heroes of the Storm', 'MiaPhysical21.pdf', 'My Games', 'My Music', 'My Pictures', 'My Videos', 'Orientation form.jpeg', 'Orientation form.png', 'Python Scripts', 'Scanned Documents', 'Stacy Masters Documents', 'Tea1', 'VS Code', 'Zoom']

# %%
os.mkdir('Tea1')

# %%
os.makedirs('Tea1/Sub-Dir-1')

# %%
os.rmdir('Tea1')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-46-8b39aef93e89> in <module>
# ----> 1 os.rmdir('Tea1')
#
# OSError: [WinError 145] The directory is not empty: 'Tea1'

# %%
os.removedirs('Tea1/Sub-Dir-1')

# %%
os.rename('Fax','Fax1')

# %%
print(os.stat('blah.png'))
# Out:
# os.stat_result(st_mode=33206, st_ino=19421773393119738, st_dev=2622976959, st_nlink=1, st_uid=0, st_gid=0, st_size=1603054, st_atime=1631591548, st_mtime=1628567532, st_ctime=1628567532)

# %%
from datetime import datetime

# %%
mod_time = os.stat('blah.png').st_mtime
print(datetime.fromtimestamp(mod_time))
# Out:
# 2021-08-09 21:52:12.670719

# %%
for dirpath, dirnames, filenames in os.walk('/Users/Stacy/Documents/'):
        print('Cureent Path:', dirpath)
        print('Directories:', dirnames)
        print('Files:', filenames)
        print()
# Out:
# Cureent Path: /Users/Stacy/Documents/
# Directories: ['Computer Science Fundamentals 6806', 'Diablo III', 'Fax1', 'GitHub', 'Heroes of the Storm', 'My Games', 'My Music', 'My Pictures', 'My Videos', 'Python Scripts', 'Scanned Documents', 'Stacy Masters Documents', 'VS Code', 'Zoom']
# Files: ['blah.png', 'Clinical Orientation Confirmation.png', 'Clinical Orientation Confirmation.tiff', 'desktop.ini', 'Document4.docx', 'MiaPhysical21.pdf', 'Orientation form.jpeg', 'Orientation form.png']
#
# Cureent Path: /Users/Stacy/Documents/Computer Science Fundamentals 6806
# Directories: ['wk 1', 'wk 2', 'wk 3', 'wk 4']
# Files: []
#
# Cureent Path: /Users/Stacy/Documents/Computer Science Fundamentals 6806\wk 1
# Directories: []
# Files: []
#
# Cureent Path: /Users/Stacy/Documents/Computer Science Fundamentals 6806\wk 2
# Directories: []
# Files: []
#
# Cureent Path: /Users/Stacy/Documents/Computer Science Fundamentals 6806\wk 3
# Directories: []
# Files: []
#
# ...

# %%
print(os.environ.get('USERPROFILE'))
# Out:
# C:\Users\Stacy

# %%
file_path = os.path.join(os.environ.get('USERPROFILE'), 'test.txt')
print(file_path)
# Out:
# C:\Users\Stacy\test.txt

# %%
print(os.path.basename('/tmp/test.txt'))
# Out:
# test.txt

# %%
print(os.path.dirname('/tmp/test.txt'))
# Out:
# /tmp

# %%
print(os.path.split('/tmp/test.txt'))
# Out:
# ('/tmp', 'test.txt')

# %%
print(os.path.exists('/tmp/test.txt'))
# Out:
# False

# %%
print(os.path.isdir('/tmp/fgdfgdrf'))
# Out:
# False

# %%
print(os.path.isfile('/tmp/fgdfgdrf'))
# Out:
# False

# %%
print(os.path.splitext('/tmp/test.txt'))
# Out:
# ('/tmp/test', '.txt')

# %%
#This is a comment

# %%
#This is the link to official Python documentation https://docs.python.org/3/

# %%
# This is the link to the OS mdoule official docuemntation https://python101.pythonlibrary.org/chapter16_os.html
